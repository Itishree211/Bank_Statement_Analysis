# %%
import pandas as pd
import tabula

# %%
hdfc_statement='sample_pdf.pdf'

# %%
hdfc=tabula.read_pdf(hdfc_statement,pages='all', pandas_options={'header': None})

# %%
print(type(hdfc), len(hdfc))
type(hdfc[0])
# Out:
# <class 'list'> 9
# pandas.core.frame.DataFrame

# %%
hf0 = hdfc[0]
print(type(hf0),len(hf0))
# Out:
# <class 'pandas.core.frame.DataFrame'> 31

# %%
hf0
# Out:
#            0                                         1                 2  \
# 0       Date                                 Narration      Chq./Ref.No.
# 1   01/02/17   EAW-421424XXXXXX3014-SWCW3332-BANGALORE  0000000000000454
# 2   05/02/17  NEFT DR-CITI0000003-CITI CARD 5328-NETBA  N036170242486261
# 3        NaN                  NK, MUM-N036170242486261               NaN
# 4   05/02/17  NEFT DR-SBIN00CARDS-SBI CREDIT CARD 0721  N036170242491276
# 5        NaN            -NETBANK, MUM-N036170242491276               NaN
# 6   05/02/17  IMPS-703622503327-ITISHREE PALAI-HDFC-XX  0000703622503327
# 7        NaN                               XXXXXX0576-               NaN
# 8   06/02/17    ACH D- TP ACH RLOAN AXIS BA-1003577981  0000006928846111
# 9   07/02/17      EMI 40180867 CHQ S40180867/1-8 02/17   000000000000000
# 10  10/02/17  NEFT DR-SCBL0036001-MANHATTAN CARD 8107-  N041170245711664
# 11       NaN             NETBANK, MUM-N041170245711664               NaN
# 12  27/02/17    NEFT CR-SBIN0005157-MR SATYAJIT APPOT-  SBIN917057105644
# 13       NaN           SATYAJIT APPOT-SBIN917057105644               NaN
# 14  28/02/17  NEFT DR-CITI0000004-ARUN MATHEW-NETBANK,  N059170251591112
# 15       NaN                      MUM-N059170251591112               NaN
# 16  28/02/17  NEFT CR-DEUT0784BBY-SIEMENS HEALTHCARE P  170224325GN00619
# 17       NaN      L-MR SATYAJIT APPOT-170224325GN00619               NaN
# 18  01/03/17   EAW-421424XXXXXX3014-SWCW3332-BANGALORE  0000000000004600
# 19  04/03/17  NEFT DR-CITI0000004-ARUN MATHEW-NETBANK,  N063170254748862
# 20       NaN                      MUM-N063170254748862               NaN
# 21  04/03/17  NEFT DR-SBIN0005157-SATYAJIT APPOT-NETBA  N063170254745417
# 22       NaN                  NK, MUM-N063170254745417               NaN
# 23  04/03/17  NEFT DR-SCBL0036001-MANHATTAN CARD 8107-  N063170254801261
# 24       NaN             NETBANK, MUM-N063170254801261               NaN
# 25  04/03/17  NEFT DR-SBIN00CARDS-SBI CREDIT CARD 0721  N063170254802320
# 26       NaN            -NETBANK, MUM-N063170254802320               NaN
# 27  06/03/17    ACH D- TP ACH RLOAN AXIS BA-1004020200  0000007235209701
# 28  07/03/17      EMI 40180867 CHQ S40180867/1-9 03/17   000000000000000
# 29  14/03/17       IHDF5186739442/BILLDKAMERICANEXPRES  0000170736286546
# 30  14/03/17       IHDF5186741814/BILLDKAMERICANEXPRES  0000170736286471
#
#            3                4             5                6
# 0   Value Dt  Withdrawal Amt.  Deposit Amt.  Closing Balance
# 1   01/02/17         6,500.00           NaN        81,942.65
# 2   06/02/17         1,031.00           NaN        80,911.65
# 3        NaN              NaN           NaN              NaN
# 4   06/02/17        51,638.00           NaN        29,273.65
# 5        NaN              NaN           NaN              NaN
# 6   06/02/17              NaN     20,000.00        49,273.65
# 7        NaN              NaN           NaN              NaN
# 8   06/02/17        13,623.00           NaN        35,650.65
# 9   07/02/17        28,769.00           NaN         6,881.65
# 10  13/02/17         6,800.00           NaN            81.65
# 11       NaN              NaN           NaN              NaN
# 12  27/02/17              NaN     15,500.00        15,581.65
# 13       NaN              NaN           NaN              NaN
# 14  28/02/17        14,597.00           NaN           984.65
# 15       NaN              NaN           NaN              NaN
# 16  28/02/17              NaN    103,733.00       104,717.65
# 17       NaN              NaN           NaN              NaN
# 18  01/03/17        10,000.00           NaN        94,717.65
# 19  04/03/17        14,380.00           NaN        80,337.65
# 20       NaN              NaN           NaN              NaN
# 21  04/03/17        13,000.00           NaN        67,337.65
# 22       NaN              NaN           NaN              NaN
# 23  04/03/17         6,823.24           NaN        60,514.41
# 24       NaN              NaN           NaN              NaN
# 25  04/03/17        15,000.00           NaN        45,514.41
# 26       NaN              NaN           NaN              NaN
# 27  06/03/17        13,623.00           NaN        31,891.41
# 28  07/03/17        28,769.00           NaN         3,122.41
# 29  14/03/17         1,000.00           NaN         2,122.41
# 30  14/03/17         2,000.00           NaN           122.41

# %%
cnt =  len(hdfc)
total_hdfc =hdfc[0].append(hdfc[1:cnt])

# %%
total_hdfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 275 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       161 non-null    object
#  1   1       273 non-null    object
#  2   2       164 non-null    object
#  3   3       163 non-null    object
#  4   4       105 non-null    object
#  5   5       66 non-null     object
#  6   6       154 non-null    object
# dtypes: object(7)
# memory usage: 17.2+ KB

# %%
total_hdfc.shape
# Out:
# (275, 7)

# %%
total_hdfc
# Out:
#            0                                         1  \
# 0       Date                                 Narration
# 1   01/02/17   EAW-421424XXXXXX3014-SWCW3332-BANGALORE
# 2   05/02/17  NEFT DR-CITI0000003-CITI CARD 5328-NETBA
# 3        NaN                  NK, MUM-N036170242486261
# 4   05/02/17  NEFT DR-SBIN00CARDS-SBI CREDIT CARD 0721
# ..       ...                                       ...
# 15       NaN                           Opening Balance
# 16       NaN                                 88,442.65
# 17       NaN           Generated On: 04-Sep-2017 16:32
# 18       NaN                                       NaN
# 19       NaN                                       NaN
#
#                          2         3                            4  \
# 0             Chq./Ref.No.  Value Dt              Withdrawal Amt.
# 1         0000000000000454  01/02/17                     6,500.00
# 2         N036170242486261  06/02/17                     1,031.00
# 3                      NaN       NaN                          NaN
# 4         N036170242491276  06/02/17                    51,638.00
# ..                     ...       ...                          ...
# 15                Dr Count  Cr Count                       Debits
# 16                     101        59                 1,320,074.26
# 17  Generated By: 39221915       NaN  Requesting Branch Code: NET
# 18                     NaN       NaN                          NaN
# 19                     NaN       NaN                          NaN
#
#                                                   5                6
# 0                                      Deposit Amt.  Closing Balance
# 1                                               NaN        81,942.65
# 2                                               NaN        80,911.65
# 3                                               NaN              NaN
# 4                                               NaN        29,273.65
# ..                                              ...              ...
# 15                              Credits Closing Bal              NaN
# 16                          1,978,628.08 746,996.47              NaN
# 17                                              NaN              NaN
# 18  This is a computer generated statement and does              NaN
# 19                           not require signature.              NaN
#
# [275 rows x 7 columns]

# %%
total_hdfc.reset_index(inplace = True,drop = True)

# %%
total_hdfc
# Out:
#             0                                         1  \
# 0        Date                                 Narration
# 1    01/02/17   EAW-421424XXXXXX3014-SWCW3332-BANGALORE
# 2    05/02/17  NEFT DR-CITI0000003-CITI CARD 5328-NETBA
# 3         NaN                  NK, MUM-N036170242486261
# 4    05/02/17  NEFT DR-SBIN00CARDS-SBI CREDIT CARD 0721
# ..        ...                                       ...
# 270       NaN                           Opening Balance
# 271       NaN                                 88,442.65
# 272       NaN           Generated On: 04-Sep-2017 16:32
# 273       NaN                                       NaN
# 274       NaN                                       NaN
#
#                           2         3                            4  \
# 0              Chq./Ref.No.  Value Dt              Withdrawal Amt.
# 1          0000000000000454  01/02/17                     6,500.00
# 2          N036170242486261  06/02/17                     1,031.00
# 3                       NaN       NaN                          NaN
# 4          N036170242491276  06/02/17                    51,638.00
# ..                      ...       ...                          ...
# 270                Dr Count  Cr Count                       Debits
# 271                     101        59                 1,320,074.26
# 272  Generated By: 39221915       NaN  Requesting Branch Code: NET
# 273                     NaN       NaN                          NaN
# 274                     NaN       NaN                          NaN
#
#                                                    5                6
# 0                                       Deposit Amt.  Closing Balance
# 1                                                NaN        81,942.65
# 2                                                NaN        80,911.65
# 3                                                NaN              NaN
# 4                                                NaN        29,273.65
# ..                                               ...              ...
# 270                              Credits Closing Bal              NaN
# 271                          1,978,628.08 746,996.47              NaN
# 272                                              NaN              NaN
# 273  This is a computer generated statement and does              NaN
# 274                           not require signature.              NaN
#
# [275 rows x 7 columns]

# %%
total_hdfc.rename(columns={0: 'Date', 1: 'Narration', 2:'Chq', 3:'ValueDt', 4:'WithDrawalAmt', 5:'DepositAmt', 6:'ClosingBalance'}, inplace=True)

# %%
total_hdfc
# Out:
#          Date                                 Narration  \
# 0        Date                                 Narration
# 1    01/02/17   EAW-421424XXXXXX3014-SWCW3332-BANGALORE
# 2    05/02/17  NEFT DR-CITI0000003-CITI CARD 5328-NETBA
# 3         NaN                  NK, MUM-N036170242486261
# 4    05/02/17  NEFT DR-SBIN00CARDS-SBI CREDIT CARD 0721
# ..        ...                                       ...
# 270       NaN                           Opening Balance
# 271       NaN                                 88,442.65
# 272       NaN           Generated On: 04-Sep-2017 16:32
# 273       NaN                                       NaN
# 274       NaN                                       NaN
#
#                         Chq   ValueDt                WithDrawalAmt  \
# 0              Chq./Ref.No.  Value Dt              Withdrawal Amt.
# 1          0000000000000454  01/02/17                     6,500.00
# 2          N036170242486261  06/02/17                     1,031.00
# 3                       NaN       NaN                          NaN
# 4          N036170242491276  06/02/17                    51,638.00
# ..                      ...       ...                          ...
# 270                Dr Count  Cr Count                       Debits
# 271                     101        59                 1,320,074.26
# 272  Generated By: 39221915       NaN  Requesting Branch Code: NET
# 273                     NaN       NaN                          NaN
# 274                     NaN       NaN                          NaN
#
#                                           DepositAmt   ClosingBalance
# 0                                       Deposit Amt.  Closing Balance
# 1                                                NaN        81,942.65
# 2                                                NaN        80,911.65
# 3                                                NaN              NaN
# 4                                                NaN        29,273.65
# ..                                               ...              ...
# 270                              Credits Closing Bal              NaN
# 271                          1,978,628.08 746,996.47              NaN
# 272                                              NaN              NaN
# 273  This is a computer generated statement and does              NaN
# 274                           not require signature.              NaN
#
# [275 rows x 7 columns]

# %%
total_hdfc[2:3]
# Out:
#        Date                                 Narration               Chq  \
# 2  05/02/17  NEFT DR-CITI0000003-CITI CARD 5328-NETBA  N036170242486261
#
#     ValueDt WithDrawalAmt DepositAmt ClosingBalance
# 2  06/02/17      1,031.00        NaN      80,911.65

# %%
for index, row in total_hdfc.iterrows():
    #skip the first record
    if index==0:
        continue
    
    x=row.Date
    
    if pd.isnull(x):
        print('Index: ',index)
        
        # Append Previous record of Narration + current Narration
        Narration_msg=total_hdfc[index-1:index]['Narration']+row.Narration
        print(Narration_msg)
        
        # Update Previous Record
        total_hdfc[index-1:index]['Narration'] = Narration_msg
# Out:
# Index:  3
# 2    NEFT DR-CITI0000003-CITI CARD 5328-NETBANK, MU...
# Name: Narration, dtype: object
# Index:  5
# 4    NEFT DR-SBIN00CARDS-SBI CREDIT CARD 0721-NETBA...
# Name: Narration, dtype: object
# Index:  7
# 6    IMPS-703622503327-ITISHREE PALAI-HDFC-XXXXXXXX...
# Name: Narration, dtype: object
# Index:  11
# 10    NEFT DR-SCBL0036001-MANHATTAN CARD 8107-NETBAN...
# Name: Narration, dtype: object
# C:\Users\Itishree\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# Index:  13
# 12    NEFT CR-SBIN0005157-MR SATYAJIT APPOT-SATYAJIT...
# Name: Narration, dtype: object
# Index:  15
# 14    NEFT DR-CITI0000004-ARUN MATHEW-NETBANK,MUM-N0...
# Name: Narration, dtype: object
# Index:  17
# 16    NEFT CR-DEUT0784BBY-SIEMENS HEALTHCARE PL-MR S...
# Name: Narration, dtype: object
# Index:  20
# 19    NEFT DR-CITI0000004-ARUN MATHEW-NETBANK,MUM-N0...
# Name: Narration, dtype: object
# Index:  22
# 21    NEFT DR-SBIN0005157-SATYAJIT APPOT-NETBANK, MU...
# Name: Narration, dtype: object
# Index:  24
# 23    NEFT DR-SCBL0036001-MANHATTAN CARD 8107-NETBAN...
# Name: Narration, dtype: object
# Index:  26
# 25    NEFT DR-SBIN00CARDS-SBI CREDIT CARD 0721-NETBA...
# Name: Narration, dtype: object
# Index:  32
# 31    NEFT CR-DEUT0784BBY-SIEMENS HEALTHCARE PL-SATY...
# Name: Narration, dtype: object
# Index:  34
# 33    NEFT DR-ICIC0000297-JYOTI RANJAN JENA-NETBANK,...
# Name: Narration, dtype: object
# Index:  36
# 35    NEFT DR-SCBL0036020-AMERICAN EXPRESS-NETBANK, ...
# Name: Narration, dtype: object
# Index:  38
# 37    NEFT DR-ICIC0006252-ITISHREE PALAI-NETBANK, MU...
# Name: Narration, dtype: object
# Index:  43
# 42    NEFT DR-ICIC0000297-JYOTI RANJAN JENA-NETBANK,...
# Name: Narration, dtype: object
# Index:  45
# 44    NEFT CR-DEUT0784BBY-SIEMENS HEALTHCARE PL-MR S...
# Name: Narration, dtype: object
# Index:  50
# 49    IMPS-709211187883-BIJAY KUMAR APAT-SBIN-XXXXXX...
# Name: Narration, dtype: object
# Index:  52
# 51    NEFT DR-SCBL0036020-AMERICAN EXPRESS-NETBANK, ...
# Name: Narration, dtype: object
# Index:  54
# 53    IMPS-709211191538-SATYAJIT APPOT-SBIN-XXXXXXX9...
# Name: Narration, dtype: object
# Index:  56
# 55    NEFT DR-SBIN00CARDS-SBI CREDIT CARD 0721-NETBA...
# Name: Narration, dtype: object
# Index:  59
# 58    NEFT CR-SBIN0005157-MR SATYAJIT APPOT-SATYAJIT...
# Name: Narration, dtype: object
# Index:  61
# 60    IMPS-709512490343-SATYAJIT APPOT-HDFC-XXXXXXXX...
# Name: Narration, dtype: object
# Index:  63
# 62    IMPS-709512522636-SATYAJIT APPOT-HDFC-XXXXXXXX...
# Name: Narration, dtype: object
# Index:  66
# 65    IMPS-709514678692-SATYAJIT APPOT-HDFC-XXXXXXXX...
# Name: Narration, dtype: object
# Index:  68
# 67    IMPS-709514682987-SATYAJIT APPOT-HDFC-XXXXXXXX...
# Name: Narration, dtype: object
# Index:  70
# 69    NEFT DR-SCBL0036001-MANHATTAN CARD 8107-NETBAN...
# Name: Narration, dtype: object
# Index:  76
# 75    NEFT DR-CITI0000003-CITI CARD 5328-NETBANK, MU...
# Name: Narration, dtype: object
# Index:  78
# 77    NEFT DR-SBIN00CARDS-SBI CREDIT CARD 0721-NETBA...
# Name: Narration, dtype: object
# Index:  84
# 83    NEFT CR-SCBL0036001-CREDIT CARD NEFT SUSPENSE ...
# Name: Narration, dtype: object
# Index:  85
# 84    PENSE ACCOUNT-SATYAJIT APPOT-SCBLN17117FE0015
# Name: Narration, dtype: object
# Index:  88
# 87    NEFT DR-SBIN0005157-SATYAJIT APPOT-NETBANK, MU...
# Name: Narration, dtype: object
# Index:  90
# 89    NEFT CR-DEUT0784BBY-SIEMENS HEALTHCARE PL-MR S...
# Name: Narration, dtype: object
# Index:  93
# 92    NEFT DR-SBIN00CARDS-SBI CREDIT CARD 0721-NETBA...
# Name: Narration, dtype: object
# Index:  95
# 94    NEFT DR-SCBL0036001-MANHATTAN CARD 8107-NETBAN...
# Name: Narration, dtype: object
# Index:  97
# 96    IMPS-712017355068-ITISHREE PALAI-HDFC-XXXXXXXX...
# Name: Narration, dtype: object
# Index:  99
# 98    NEFT DR-ICIC0006252-ITISHREE PALAI-NETBANK, MU...
# Name: Narration, dtype: object
# Index:  101
# 100    NEFT DR-SBIN0005157-SATYAJIT APPOT-NETBANK, MU...
# Name: Narration, dtype: object
# Index:  105
# 104    POS 421424XXXXXX3014 MAMATHA GIRISH K POS DEBIT
# Name: Narration, dtype: object
# Index:  111
# 110    NEFT DR-CITI0000004-ARUN MATHEW-NETBANK,MUM-N1...
# Name: Narration, dtype: object
# Index:  114
# 113    IMPS-713407814864-SATYAJIT APPOT-HDFC-XXXXXXXX...
# Name: Narration, dtype: object
# Index:  119
# 118    IMPS-714716832369-SATYAJIT APPOT-HDFC-XXXXXXXX...
# Name: Narration, dtype: object
# Index:  121
# 120    IMPS-714816901269-MR SATYAJIT APPOT-HDFC-XXXXX...
# Name: Narration, dtype: object
# Index:  124
# 123    NEFT CR-DEUT0784BBY-SIEMENS HEALTHCARE PL-MR S...
# Name: Narration, dtype: object
# Index:  126
# 125    NEFT DR-SBIN0005157-BIJAY KUMAR APAT-NETBANK, ...
# Name: Narration, dtype: object
# Index:  130
# 129    NWD-421424XXXXXX3014-CUBFI394-KORAMANGALA
# Name: Narration, dtype: object
# Index:  133
# 132    NEFT DR-CITI0000003-CITI CARD 5328-NETBANK, MU...
# Name: Narration, dtype: object
# Index:  135
# 134    NEFT DR-SCBL0036001-LOAN ACCOUNT-NETBANK, MUM-...
# Name: Narration, dtype: object
# Index:  138
# 137    RD CLOSURE THROUGH NET BANKING - 50400092461799
# Name: Narration, dtype: object
# Index:  140
# 139    NEFT CR-SBIN0005157-MR SATYAJIT APPOT-SATYAJIT...
# Name: Narration, dtype: object
# Index:  142
# 141    NEFT DR-SCBL0036001-MANHATTAN CARD 8107-NETBAN...
# Name: Narration, dtype: object
# Index:  144
# 143    NEFT DR-SBIN00CARDS-SBI CREDIT CARD 0721-NETBA...
# Name: Narration, dtype: object
# Index:  146
# 145    IMPS-716109199086-SATYAJIT APPOT-HDFC-XXXXXXXX...
# Name: Narration, dtype: object
# Index:  148
# 147    IMPS-716109206596-SATYAJIT APPOT-HDFC-XXXXXXXX...
# Name: Narration, dtype: object
# Index:  150
# 149    IMPS-716109207820-SATYAJIT APPOT-HDFC-XXXXXXXX...
# Name: Narration, dtype: object
# Index:  152
# 151    IMPS-716109226539-SATYAJIT APPOT-HDFC-XXXXXXXX...
# Name: Narration, dtype: object
# Index:  154
# 153    IMPS-716109232730-SATYAJIT APPOT-HDFC-XXXXXXXX...
# Name: Narration, dtype: object
# Index:  156
# 155    NEFT DR-SBIN00CARDS-SBI CREDIT CARD 0721-NETBA...
# Name: Narration, dtype: object
# Index:  159
# 158    NEFT DR-SBIN0000850-V MANIKANTA TAMMI-NETBANK,...
# Name: Narration, dtype: object
# Index:  161
# 160    NEFT CR-ICIC0SF0002-JYOTI RANJAN JENA-SATYAJIT...
# Name: Narration, dtype: object
# Index:  163
# 162    IMPS-716812527290-SATYAJIT APPOT-HDFC-XXXXXXXX...
# Name: Narration, dtype: object
# Index:  165
# 164    NEFT DR-CITI0000004-ARUN MATHEW-NETBANK,MUM-N1...
# Name: Narration, dtype: object
# Index:  167
# 166    IMPS-717122479751-ITISHREE PALAI-HDFC-XXXXXXXX...
# Name: Narration, dtype: object
# Index:  171
# 170    NEFT CR-DEUT0784BBY-SIEMENS HEALTHCARE PL-MR S...
# Name: Narration, dtype: object
# Index:  174
# 173    NEFT DR-SBIN0005157-BIJAY KUMAR APAT-NETBANK, ...
# Name: Narration, dtype: object
# Index:  176
# 175    NEFT DR-ICIC0000297-JYOTI RANJAN JENA-NETBANK,...
# Name: Narration, dtype: object
# Index:  178
# 177    NEFT DR-SCBL0036001-MANHATTAN CARD 8107-NETBAN...
# Name: Narration, dtype: object
# Index:  180
# 179    NEFT DR-SCBL0036001-LOAN ACCOUNT-NETBANK, MUM-...
# Name: Narration, dtype: object
# Index:  186
# 185    NEFT DR-SBIN0000850-V MANIKANTA TAMMI-NETBANK,...
# Name: Narration, dtype: object
# Index:  188
# 187    IMPS-718913024222-SATYAJIT APPOT-HDFC-XXXXXXXX...
# Name: Narration, dtype: object
# Index:  190
# 189    IMPS-718913024979-SATYAJIT APPOT-HDFC-XXXXXXXX...
# Name: Narration, dtype: object
# Index:  192
# 191    IMPS-718913026221-SATYAJIT APPOT-HDFC-XXXXXXXX...
# Name: Narration, dtype: object
# Index:  194
# 193    IMPS-718913028311-SATYAJIT APPOT-HDFC-XXXXXXXX...
# Name: Narration, dtype: object
# Index:  196
# 195    NEFT DR-SBIN00CARDS-SBI CREDIT CARD 0721-NETBA...
# Name: Narration, dtype: object
# Index:  198
# 197    IMPS-719020529133-SATYAJIT APPOT-HDFC-XXXXXXXX...
# Name: Narration, dtype: object
# Index:  200
# 199    IMPS-719020529151-SATYAJIT APPOT-HDFC-XXXXXXXX...
# Name: Narration, dtype: object
# Index:  202
# 201    IMPS-719020543631-SATYAJIT APPOT-HDFC-XXXXXXXX...
# Name: Narration, dtype: object
# Index:  204
# 203    IMPS-719020547029-SATYAJIT APPOT-HDFC-XXXXXXXX...
# Name: Narration, dtype: object
# Index:  206
# 205    NEFT DR-SBIN00CARDS-SBI CREDIT CARD 0721-NETBA...
# Name: Narration, dtype: object
# Index:  208
# 207    IMPS-719023696813-ITISHREE PALAI-HDFC-XXXXXXXX...
# Name: Narration, dtype: object
# Index:  210
# 209    NEFT DR-SBIN00CARDS-SBI CREDIT CARD 0721-NETBA...
# Name: Narration, dtype: object
# Index:  212
# 211    NEFT CR-KKBK0000958-SANGHAMITRA GUDU-SATYAJIT ...
# Name: Narration, dtype: object
# Index:  214
# 213    IMPS-720520154788-ARUN MATHEW-CITI-XXXXXX0801-...
# Name: Narration, dtype: object
# Index:  216
# 215    POS 421424XXXXXX3014 CARE CHEMIST POS DEBIT
# Name: Narration, dtype: object
# Index:  218
# 217    POS 421424XXXXXX3014 SWARAJ HYPERMARK POS DEBIT
# Name: Narration, dtype: object
# Index:  220
# 219    NEFT CR-DEUT0784BBY-SIEMENS HEALTHCARE PL-MR S...
# Name: Narration, dtype: object
# Index:  222
# 221    NEFT DR-SBIN0005157-BIJAY KUMAR APAT-NETBANK, ...
# Name: Narration, dtype: object
# Index:  225
# 224    NEFT DR-SCBL0036001-LOAN ACCOUNT-NETBANK, MUM-...
# Name: Narration, dtype: object
# Index:  227
# 226    NEFT DR-SCBL0036001-MANHATTAN CARD 8107-NETBAN...
# Name: Narration, dtype: object
# Index:  229
# 228    NEFT DR-SBIN0000850-V MANIKANTA TAMMI-NETBANK,...
# Name: Narration, dtype: object
# Index:  231
# 230    NEFT DR-SBIN00CARDS-SBI CREDIT CARD 0721-NETBA...
# Name: Narration, dtype: object
# Index:  236
# 235    IMPS-721921100708-BIJAY KUMAR APAT-SBIN-XXXXXX...
# Name: Narration, dtype: object
# Index:  238
# 237    IMPS-722208391535-SATYAJIT APPOT-HDFC-XXXXXXXX...
# Name: Narration, dtype: object
# Index:  240
# 239    IMPS-722208391652-SATYAJIT APPOT-HDFC-XXXXXXXX...
# Name: Narration, dtype: object
# Index:  242
# 241    IMPS-722208391796-SATYAJIT APPOT-HDFC-XXXXXXXX...
# Name: Narration, dtype: object
# Index:  244
# 243    IMPS-722208391978-SATYAJIT APPOT-HDFC-XXXXXXXX...
# Name: Narration, dtype: object
# Index:  246
# 245    IMPS-722208716276-MR SATYAJIT APPOT-HDFC-XXXXX...
# Name: Narration, dtype: object
# Index:  248
# 247    NEFT DR-SBIN00CARDS-SBI CREDIT CARD 0721-NETBA...
# Name: Narration, dtype: object
# Index:  250
# 249    IMPS-722523301540-SATYAJIT APPOT-HDFC-XXXXXXXX...
# Name: Narration, dtype: object
# Index:  252
# 251    IMPS-722523301739-SATYAJIT APPOT-HDFC-XXXXXXXX...
# Name: Narration, dtype: object
# Index:  254
# 253    IMPS-722523302558-SATYAJIT APPOT-HDFC-XXXXXXXX...
# Name: Narration, dtype: object
# Index:  256
# 255    IMPS-722523304093-SATYAJIT APPOT-HDFC-XXXXXXXX...
# Name: Narration, dtype: object
# Index:  258
# 257    NEFT DR-CITI0000004-ARUN MATHEW-NETBANK,MUM-N2...
# Name: Narration, dtype: object
# Index:  260
# 259    NEFT CR-SBIN0008879-BARIK KUMAR RAJAT-SATYAJIT...
# Name: Narration, dtype: object
# Index:  262
# 261    NEFT CR-SBIN0000300-EMPLOYEE PROVIDENT FUND OR...
# Name: Narration, dtype: object
# Index:  263
# 262    UND ORGANIZATIO-SATYAJIT APPOT-SBIN517236169771
# Name: Narration, dtype: object
# Index:  265
# 264    NEFT CR-DEUT0784BBY-SIEMENS HEALTHCARE PL-MR S...
# Name: Narration, dtype: object
# Index:  267
# 266    IMPS-724412272781-ITISHREE PALAI-HDFC-XXXXXXXX...
# Name: Narration, dtype: object
# Index:  269
# 268    NWD-421424XXXXXX3014-0888EP05-BANGALORESTATEME...
# Name: Narration, dtype: object
# Index:  270
# 269    STATEMENT SUMMARY :-Opening Balance
# Name: Narration, dtype: object
# Index:  271
# 270    Opening Balance88,442.65
# Name: Narration, dtype: object
# Index:  272
# 271    88,442.65Generated On: 04-Sep-2017 16:32
# Name: Narration, dtype: object
# Index:  273
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, str_rep)
#     148     try:
# --> 149         result = expressions.evaluate(op, str_rep, left, right)
#     150     except TypeError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     120     if result is None:
# --> 121         result = _evaluate_standard(op, op_str, a, b)
#     122
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      69     with np.errstate(all="ignore"):
# ---> 70         return op(a, b)
#      71
#
# TypeError: must be str, not float
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-e5f0eb77380e> in <module>()
#      10
#      11         # Append Previous record of Narration + current Narration
# ---> 12         Narration_msg=total_hdfc[index-1:index]['Narration']+row.Narration
#      13         print(Narration_msg)
#      14
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(left, right)
#     501         lvalues = extract_array(left, extract_numpy=True)
#     502         rvalues = extract_array(right, extract_numpy=True)
# --> 503         result = arithmetic_op(lvalues, rvalues, op, str_rep)
#     504
#     505         return _construct_result(left, result, index=left.index, name=res_name)
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in arithmetic_op(left, right, op, str_rep)
#     195     else:
#     196         with np.errstate(all="ignore"):
# --> 197             res_values = na_arithmetic_op(lvalues, rvalues, op, str_rep)
#     198
#     199     return res_values
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, str_rep)
#     149         result = expressions.evaluate(op, str_rep, left, right)
#     150     except TypeError:
# --> 151         result = masked_arith_op(left, right, op)
#     152
#     153     return missing.dispatch_fill_zeros(op, left, right, result)
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in masked_arith_op(x, y, op)
#     110         if mask.any():
#     111             with np.errstate(all="ignore"):
# --> 112                 result[mask] = op(xrav[mask], y)
#     113
#     114     result, _ = maybe_upcast_putmask(result, ~mask, np.nan)
#
# TypeError: must be str, not float

# %%
total_hdfc
# Out:
#          Date                                          Narration  \
# 0        Date                                          Narration
# 1    01/02/17            EAW-421424XXXXXX3014-SWCW3332-BANGALORE
# 2    05/02/17  NEFT DR-CITI0000003-CITI CARD 5328-NETBANK, MU...
# 3         NaN                           NK, MUM-N036170242486261
# 4    05/02/17  NEFT DR-SBIN00CARDS-SBI CREDIT CARD 0721-NETBA...
# ..        ...                                                ...
# 270       NaN                           Opening Balance88,442.65
# 271       NaN           88,442.65Generated On: 04-Sep-2017 16:32
# 272       NaN                    Generated On: 04-Sep-2017 16:32
# 273       NaN                                                NaN
# 274       NaN                                                NaN
#
#                         Chq   ValueDt                WithDrawalAmt  \
# 0              Chq./Ref.No.  Value Dt              Withdrawal Amt.
# 1          0000000000000454  01/02/17                     6,500.00
# 2          N036170242486261  06/02/17                     1,031.00
# 3                       NaN       NaN                          NaN
# 4          N036170242491276  06/02/17                    51,638.00
# ..                      ...       ...                          ...
# 270                Dr Count  Cr Count                       Debits
# 271                     101        59                 1,320,074.26
# 272  Generated By: 39221915       NaN  Requesting Branch Code: NET
# 273                     NaN       NaN                          NaN
# 274                     NaN       NaN                          NaN
#
#                                           DepositAmt   ClosingBalance
# 0                                       Deposit Amt.  Closing Balance
# 1                                                NaN        81,942.65
# 2                                                NaN        80,911.65
# 3                                                NaN              NaN
# 4                                                NaN        29,273.65
# ..                                               ...              ...
# 270                              Credits Closing Bal              NaN
# 271                          1,978,628.08 746,996.47              NaN
# 272                                              NaN              NaN
# 273  This is a computer generated statement and does              NaN
# 274                           not require signature.              NaN
#
# [275 rows x 7 columns]

# %%
# Drop the first record
total_hdfc=total_hdfc.drop(0)

# %%
total_hdfc.head()
# Out:
#        Date                                          Narration  \
# 1  01/02/17            EAW-421424XXXXXX3014-SWCW3332-BANGALORE
# 2  05/02/17  NEFT DR-CITI0000003-CITI CARD 5328-NETBANK, MU...
# 3       NaN                           NK, MUM-N036170242486261
# 4  05/02/17  NEFT DR-SBIN00CARDS-SBI CREDIT CARD 0721-NETBA...
# 5       NaN                     -NETBANK, MUM-N036170242491276
#
#                 Chq   ValueDt WithDrawalAmt DepositAmt ClosingBalance
# 1  0000000000000454  01/02/17      6,500.00        NaN      81,942.65
# 2  N036170242486261  06/02/17      1,031.00        NaN      80,911.65
# 3               NaN       NaN           NaN        NaN            NaN
# 4  N036170242491276  06/02/17     51,638.00        NaN      29,273.65
# 5               NaN       NaN           NaN        NaN            NaN

# %%
# drop record if date filed is null
final_hdfc=total_hdfc.dropna(subset=['Date'])

# %%
final_hdfc
# Out:
#          Date                                          Narration  \
# 1    01/02/17            EAW-421424XXXXXX3014-SWCW3332-BANGALORE
# 2    05/02/17  NEFT DR-CITI0000003-CITI CARD 5328-NETBANK, MU...
# 4    05/02/17  NEFT DR-SBIN00CARDS-SBI CREDIT CARD 0721-NETBA...
# 6    05/02/17  IMPS-703622503327-ITISHREE PALAI-HDFC-XXXXXXXX...
# 8    06/02/17             ACH D- TP ACH RLOAN AXIS BA-1003577981
# ..        ...                                                ...
# 259  18/08/17  NEFT CR-SBIN0008879-BARIK KUMAR RAJAT-SATYAJIT...
# 261  24/08/17  NEFT CR-SBIN0000300-EMPLOYEE PROVIDENT FUND OR...
# 264  31/08/17  NEFT CR-DEUT0784BBY-SIEMENS HEALTHCARE PL-MR S...
# 266  01/09/17  IMPS-724412272781-ITISHREE PALAI-HDFC-XXXXXXXX...
# 268  01/09/17  NWD-421424XXXXXX3014-0888EP05-BANGALORESTATEME...
#
#                   Chq   ValueDt WithDrawalAmt             DepositAmt  \
# 1    0000000000000454  01/02/17      6,500.00                    NaN
# 2    N036170242486261  06/02/17      1,031.00                    NaN
# 4    N036170242491276  06/02/17     51,638.00                    NaN
# 6    0000703622503327  06/02/17           NaN              20,000.00
# 8    0000006928846111  06/02/17     13,623.00                    NaN
# ..                ...       ...           ...                    ...
# 259  SBIN117230106825  18/08/17           NaN      1,000.00 1,350.47
# 261  SBIN517236169771  24/08/17           NaN  500,000.00 501,350.47
# 264  170831118GN00591  31/08/17           NaN  105,646.00 606,996.47
# 266  0000724412272781  01/09/17           NaN  150,000.00 756,996.47
# 268  0000724420012992  01/09/17     10,000.00             746,996.47
#
#     ClosingBalance
# 1        81,942.65
# 2        80,911.65
# 4        29,273.65
# 6        49,273.65
# 8        35,650.65
# ..             ...
# 259            NaN
# 261            NaN
# 264            NaN
# 266            NaN
# 268            NaN
#
# [160 rows x 7 columns]

# %%
final_hdfc.reset_index(inplace = True,drop = True)

# %%
final_hdfc
# Out:
#          Date                                          Narration  \
# 0    01/02/17            EAW-421424XXXXXX3014-SWCW3332-BANGALORE
# 1    05/02/17  NEFT DR-CITI0000003-CITI CARD 5328-NETBANK, MU...
# 2    05/02/17  NEFT DR-SBIN00CARDS-SBI CREDIT CARD 0721-NETBA...
# 3    05/02/17  IMPS-703622503327-ITISHREE PALAI-HDFC-XXXXXXXX...
# 4    06/02/17             ACH D- TP ACH RLOAN AXIS BA-1003577981
# ..        ...                                                ...
# 155  18/08/17  NEFT CR-SBIN0008879-BARIK KUMAR RAJAT-SATYAJIT...
# 156  24/08/17  NEFT CR-SBIN0000300-EMPLOYEE PROVIDENT FUND OR...
# 157  31/08/17  NEFT CR-DEUT0784BBY-SIEMENS HEALTHCARE PL-MR S...
# 158  01/09/17  IMPS-724412272781-ITISHREE PALAI-HDFC-XXXXXXXX...
# 159  01/09/17  NWD-421424XXXXXX3014-0888EP05-BANGALORESTATEME...
#
#                   Chq   ValueDt WithDrawalAmt             DepositAmt  \
# 0    0000000000000454  01/02/17      6,500.00                    NaN
# 1    N036170242486261  06/02/17      1,031.00                    NaN
# 2    N036170242491276  06/02/17     51,638.00                    NaN
# 3    0000703622503327  06/02/17           NaN              20,000.00
# 4    0000006928846111  06/02/17     13,623.00                    NaN
# ..                ...       ...           ...                    ...
# 155  SBIN117230106825  18/08/17           NaN      1,000.00 1,350.47
# 156  SBIN517236169771  24/08/17           NaN  500,000.00 501,350.47
# 157  170831118GN00591  31/08/17           NaN  105,646.00 606,996.47
# 158  0000724412272781  01/09/17           NaN  150,000.00 756,996.47
# 159  0000724420012992  01/09/17     10,000.00             746,996.47
#
#     ClosingBalance
# 0        81,942.65
# 1        80,911.65
# 2        29,273.65
# 3        49,273.65
# 4        35,650.65
# ..             ...
# 155            NaN
# 156            NaN
# 157            NaN
# 158            NaN
# 159            NaN
#
# [160 rows x 7 columns]

# %%
final_hdfc.tail(10)
# Out:
#          Date                                          Narration  \
# 150  13/08/17  IMPS-722523301540-SATYAJIT APPOT-HDFC-XXXXXXXX...
# 151  13/08/17  IMPS-722523301739-SATYAJIT APPOT-HDFC-XXXXXXXX...
# 152  13/08/17  IMPS-722523302558-SATYAJIT APPOT-HDFC-XXXXXXXX...
# 153  13/08/17  IMPS-722523304093-SATYAJIT APPOT-HDFC-XXXXXXXX...
# 154  13/08/17  NEFT DR-CITI0000004-ARUN MATHEW-NETBANK,MUM-N2...
# 155  18/08/17  NEFT CR-SBIN0008879-BARIK KUMAR RAJAT-SATYAJIT...
# 156  24/08/17  NEFT CR-SBIN0000300-EMPLOYEE PROVIDENT FUND OR...
# 157  31/08/17  NEFT CR-DEUT0784BBY-SIEMENS HEALTHCARE PL-MR S...
# 158  01/09/17  IMPS-724412272781-ITISHREE PALAI-HDFC-XXXXXXXX...
# 159  01/09/17  NWD-421424XXXXXX3014-0888EP05-BANGALORESTATEME...
#
#                   Chq   ValueDt WithDrawalAmt             DepositAmt  \
# 150  0000722523301540  14/08/17           NaN               5,000.00
# 151  0000722523301739  14/08/17           NaN               5,000.00
# 152  0000722523302558  14/08/17           NaN               4,000.00
# 153  0000722523304093  14/08/17           NaN       500.00 15,082.47
# 154  N225170348920451  14/08/17     14,732.00                 350.47
# 155  SBIN117230106825  18/08/17           NaN      1,000.00 1,350.47
# 156  SBIN517236169771  24/08/17           NaN  500,000.00 501,350.47
# 157  170831118GN00591  31/08/17           NaN  105,646.00 606,996.47
# 158  0000724412272781  01/09/17           NaN  150,000.00 756,996.47
# 159  0000724420012992  01/09/17     10,000.00             746,996.47
#
#     ClosingBalance
# 150       5,582.47
# 151      10,582.47
# 152      14,582.47
# 153            NaN
# 154            NaN
# 155            NaN
# 156            NaN
# 157            NaN
# 158            NaN
# 159            NaN

# %%
final_hdfc.to_csv('final_hdfc.csv',index = False, header=True)

# %%
df=pd.read_csv('final_hdfc1.csv')

# %%
df.tail(10)
# Out:
#          Date                                          Narration  \
# 150  13/08/17  IMPS-722523301540-SATYAJIT APPOT-HDFC-XXXXXXXX...
# 151  13/08/17  IMPS-722523301739-SATYAJIT APPOT-HDFC-XXXXXXXX...
# 152  13/08/17  IMPS-722523302558-SATYAJIT APPOT-HDFC-XXXXXXXX...
# 153  13/08/17  IMPS-722523304093-SATYAJIT APPOT-HDFC-XXXXXXXX...
# 154  13/08/17  NEFT DR-CITI0000004-ARUN MATHEW-NETBANK,MUM-N2...
# 155  18/08/17  NEFT CR-SBIN0008879-BARIK KUMAR RAJAT-SATYAJIT...
# 156  24/08/17  NEFT CR-SBIN0000300-EMPLOYEE PROVIDENT FUND OR...
# 157  31/08/17  NEFT CR-DEUT0784BBY-SIEMENS HEALTHCARE PL-MR S...
# 158  01/09/17  IMPS-724412272781-ITISHREE PALAI-HDFC-XXXXXXXX...
# 159  01/09/17            NWD-421424XXXXXX3014-0888EP05-BANGALORE
#
#                   Chq   ValueDt WithDrawalAmt  DepositAmt ClosingBalance
# 150  0000722523301540  14/08/17           NaN    5,000.00       5,582.47
# 151  0000722523301739  14/08/17           NaN    5,000.00      10,582.47
# 152  0000722523302558  14/08/17           NaN    4,000.00      14,582.47
# 153  0000722523304093  14/08/17           NaN      500.00      15,082.47
# 154  N225170348920451  14/08/17     14,732.00         NaN         350.47
# 155  SBIN117230106825  18/08/17           NaN    1,000.00       1,350.47
# 156  SBIN517236169771  24/08/17           NaN  500,000.00     501,350.47
# 157  170831118GN00591  31/08/17           NaN  105,646.00     606,996.47
# 158  0000724412272781  01/09/17           NaN  150,000.00     756,996.47
# 159  0000724420012992  01/09/17     10,000.00         NaN     746,996.47

# %%
df['DepositAmt']=df['DepositAmt'].str.replace(',', '').astype(float)

# %%
df['WithDrawalAmt']=df['WithDrawalAmt'].str.replace(',', '').astype(float)

# %%
df['ClosingBalance']=df['ClosingBalance'].str.replace(',', '').astype(float)

# %%
df.head()
# Out:
#        Date                                          Narration  \
# 0  01/02/17            EAW-421424XXXXXX3014-SWCW3332-BANGALORE
# 1  05/02/17  NEFT DR-CITI0000003-CITI CARD 5328-NETBANK, MU...
# 2  05/02/17  NEFT DR-SBIN00CARDS-SBI CREDIT CARD 0721-NETBA...
# 3  05/02/17  IMPS-703622503327-ITISHREE PALAI-HDFC-XXXXXXXX...
# 4  06/02/17             ACH D- TP ACH RLOAN AXIS BA-1003577981
#
#                 Chq   ValueDt  WithDrawalAmt  DepositAmt  ClosingBalance
# 0  0000000000000454  01/02/17         6500.0         NaN        81942.65
# 1  N036170242486261  06/02/17         1031.0         NaN        80911.65
# 2  N036170242491276  06/02/17        51638.0         NaN        29273.65
# 3  0000703622503327  06/02/17            NaN     20000.0        49273.65
# 4  0000006928846111  06/02/17        13623.0         NaN        35650.65

# %% [markdown]
# ### Connect to database

# %%
import sqlite3

# %%
conn=sqlite3.connect('Bank_Statement.db')  #Database name is "Bank_Statement.db"

# %%
c=conn.cursor()

# %%
c.execute('''CREATE TABLE bank_stt (Date date, Narration varchar2, Chq varchar2, ValueDt date, 
          WithDrawalAmt float, DepositAmt float, ClosingBalance float)''')
conn.commit()

# %%
df.to_sql('bank_stt', conn, if_exists='replace', index = False)

# %%
c.execute('''  
SELECT * FROM bank_stt
          ''')

# %%
for row in c.fetchall():
    print(row)
# Out:
# ('01/02/17', 'EAW-421424XXXXXX3014-SWCW3332-BANGALORE', '0000000000000454', '01/02/17', '6,500.00', None, '81,942.65')
# ('05/02/17', 'NEFT DR-CITI0000003-CITI CARD 5328-NETBANK, MUM-N036170242486261', 'N036170242486261', '06/02/17', '1,031.00', None, '80,911.65')
# ('05/02/17', 'NEFT DR-SBIN00CARDS-SBI CREDIT CARD 0721-NETBANK, MUM-N036170242491276', 'N036170242491276', '06/02/17', '51,638.00', None, '29,273.65')
# ('05/02/17', 'IMPS-703622503327-ITISHREE PALAI-HDFC-XXXXXXXX0576-', '0000703622503327', '06/02/17', None, '20,000.00', '49,273.65')
# ('06/02/17', 'ACH D- TP ACH RLOAN AXIS BA-1003577981', '0000006928846111', '06/02/17', '13,623.00', None, '35,650.65')
# ('07/02/17', 'EMI 40180867 CHQ S40180867/1-8 02/17', '000000000000000', '07/02/17', '28,769.00', None, '6,881.65')
# ('10/02/17', 'NEFT DR-SCBL0036001-MANHATTAN CARD 8107-NETBANK, MUM-N041170245711664', 'N041170245711664', '13/02/17', '6,800.00', None, '81.65')
# ('27/02/17', 'NEFT CR-SBIN0005157-MR SATYAJIT APPOT-SATYAJIT APPOT-SBIN917057105644', 'SBIN917057105644', '27/02/17', None, '15,500.00', '15,581.65')
# ('28/02/17', 'NEFT DR-CITI0000004-ARUN MATHEW-NETBANK,MUM-N059170251591112', 'N059170251591112', '28/02/17', '14,597.00', None, '984.65')
# ('28/02/17', 'NEFT CR-DEUT0784BBY-SIEMENS HEALTHCARE PL-MR SATYAJIT APPOT-170224325GN00619', '170224325GN00619', '28/02/17', None, '103,733.00', '104,717.65')
# ('01/03/17', 'EAW-421424XXXXXX3014-SWCW3332-BANGALORE', '0000000000004600', '01/03/17', '10,000.00', None, '94,717.65')
# ('04/03/17', 'NEFT DR-CITI0000004-ARUN MATHEW-NETBANK
# ('02/08/17', 'NEFT DR-SCBL0036001-LOAN ACCOUNT-NETBANK, MUM-N214170342082190', 'N214170342082190', '02/08/17', '10,000.00', None, '80,393.47')
# ('02/08/17', 'NEFT DR-SCBL0036001-MANHATTAN CARD 8107-NETBANK, MUM-N214170342079601', 'N214170342079601', '02/08/17', '1,997.00', None, '78,396.47')
# ('02/08/17', 'NEFT DR-SBIN0000850-V MANIKANTA TAMMI-NETBANK, MUM-N214170342087928', 'N214170342087928', '02/08/17', '2,000.00', None, '76,396.47')
# ('02/08/17', 'NEFT DR-SBIN00CARDS-SBI CREDIT CARD 0721-NETBANK, MUM-N214170342100922', 'N214170342100922', '02/08/17', '27,322.00', None, '49,074.47')
# ('05/08/17', 'NWD-421424XXXXXX3014-0888E074-BANGALORE', '0000721713020480', '05/08/17', '1,000.00', None, '48,074.47')
# ('05/08/17', 'ACH D- TP ACH RLOAN AXIS BA-1006623689', '0000009335586373', '05/08/17', '13,623.00', None, '34,451.47')
# ('07/08/17', 'EMI 40180867 CHQ S40180867/1-14 08/17', '000000000000000', '07/08/17', '28,769.00', None, '5,682.47')
# ('07/08/17', 'IMPS-721921100708-BIJAY KUMAR APAT-SBIN-XXXXXXX8315-TO BAPA', '0000721921100708', '07/08/17', '5,000.00', None, '682.47')
# ('10/08/17', 'IMPS-722208391535-SATYAJIT APPOT-HDFC-XXXXXXXXXX0001-COMMENTS', '0000722208391535', '10/08/17', None, '5,000.00', '5,682.47')
# ('10/08/17', 'IMPS-722208391652-SATYAJIT APPOT-HDFC-XXXXXXXXXX0001-COMMENTS', '0000722208391652', '10/08/17', None, '5,000.00', '10,682.47')
# ('10/08/17', 'IMPS-722208391796-SATYAJIT APPOT-HDFC-XXXXXXXXXX0001-COMMENTS', '0000722208391796', '10/08/17', None, '5,000.00', '15,682.47')
# ('10/08/17', 'IMPS-722208391978-SATYAJIT APPOT-HDFC-XXXXXXXXXX0001-COMMENTS', '0000722208391978', '10/08/17', None, '4,300.00', '19,982.47')
# ('10/08/17', 'IMPS-722208716276-MR SATYAJIT APPOT-HDFC-XXXXXXXXXXXXX9873-INETIMPS00033712574', '0000722208716276', '10/08/17', None, '600.00', '20,582.47')
# ('10/08/17', 'NEFT DR-SBIN00CARDS-SBI CREDIT CARD 0721-NETBANK, MUM-N222170347141136', 'N222170347141136', '10/08/17', '20,000.00', None, '582.47')
# ('13/08/17', 'IMPS-722523301540-SATYAJIT APPOT-HDFC-XXXXXXXXXX0001-COMMENTS', '0000722523301540', '14/08/17', None, '5,000.00', '5,582.47')
# ('13/08/17', 'IMPS-722523301739-SATYAJIT APPOT-HDFC-XXXXXXXXXX0001-COMMENTS', '0000722523301739', '14/08/17', None, '5,000.00', '10,582.47')
# ('13/08/17', 'IMPS-722523302558-SATYAJIT APPOT-HDFC-XXXXXXXXXX0001-COMMENTS', '0000722523302558', '14/08/17', None, '4,000.00', '14,582.47')
# ('13/08/17', 'IMPS-722523304093-SATYAJIT APPOT-HDFC-XXXXXXXXXX0001-COMMENTS', '0000722523304093', '14/08/17', None, '500.00', '15,082.47')
# ('13/08/17', 'NEFT DR-CITI0000004-ARUN MATHEW-NETBANK,MUM-N225170348920451', 'N225170348920451', '14/08/17', '14,732.00', None, '350.47')
# ('18/08/17', 'NEFT CR-SBIN0008879-BARIK KUMAR RAJAT-SATYAJIT APPOT-SBIN117230106825', 'SBIN117230106825', '18/08/17', None, '1,000.00', '1,350.47')
# ('24/08/17', 'NEFT CR-SBIN0000300-EMPLOYEE PROVIDENT FUND ORGANIZATIO-SATYAJIT APPOT-SBIN51723', 'SBIN517236169771', '24/08/17', None, '500,000.00', '501,350.47')
# ('31/08/17', 'NEFT CR-DEUT0784BBY-SIEMENS HEALTHCARE PL-MR SATYAJIT APPOT-170831118GN00591', '170831118GN00591', '31/08/17', None, '105,646.00', '606,996.47')
# ('01/09/17', 'IMPS-724412272781-ITISHREE PALAI-HDFC-XXXXXXXX0576-TO SATYA', '0000724412272781', '01/09/17', None, '150,000.00', '756,996.47')
# ('01/09/17', 'NWD-421424XXXXXX3014-0888EP05-BANGALORE', '0000724420012992', '01/09/17', '10,000.00', None, '746,996.47')

# %% [markdown]
# ### Working With Excel

# %%
import openpyxl

# %%
# Give the location of the file
#path = "C:\\Users\\Itishree\\Downloads\\ICICI_Stmt.xlsx"

# %%
#workbook = openpyxl.load_workbook(path)
workbook =  openpyxl.load_workbook('ICICI_Stmt.xlsx')

# %%
worksheet = workbook.active

# %%
Total_Credit=df['DepositAmt'].sum()
print(Total_Credit)
# Out:
# 1978628.08

# %%
worksheet['D3']=Total_Credit

# %%
Balance=df.iloc[-1][-1]
print(Balance)
# Out:
# 746996.47

# %%
worksheet['C3']=Balance

# %%
#df['ClosingBalance'].sum() / df.index.size
Avg_Bal_6months=df['ClosingBalance'].mean()
print(Avg_Bal_6months)
# Out:
# 62080.455437499986

# %%
worksheet['B11']=Avg_Bal_6months

# %%
workbook.save('ICICI_Stmt.xlsx')

# %%
df.dtypes
# Out:
# Date              datetime64[ns]
# Narration                 object
# Chq                       object
# ValueDt                   object
# WithDrawalAmt            float64
# DepositAmt               float64
# ClosingBalance           float64
# dtype: object

# %%
#df['Date']=df['Date'].astype('date')
df['Date']= pd.to_datetime(df['Date'])

# %%
df.head()
# Out:
#         Date                                          Narration  \
# 0 2017-01-02            EAW-421424XXXXXX3014-SWCW3332-BANGALORE
# 1 2017-05-02  NEFT DR-CITI0000003-CITI CARD 5328-NETBANK, MU...
# 2 2017-05-02  NEFT DR-SBIN00CARDS-SBI CREDIT CARD 0721-NETBA...
# 3 2017-05-02  IMPS-703622503327-ITISHREE PALAI-HDFC-XXXXXXXX...
# 4 2017-06-02             ACH D- TP ACH RLOAN AXIS BA-1003577981
#
#                 Chq   ValueDt  WithDrawalAmt  DepositAmt  ClosingBalance
# 0  0000000000000454  01/02/17         6500.0         NaN        81942.65
# 1  N036170242486261  06/02/17         1031.0         NaN        80911.65
# 2  N036170242491276  06/02/17        51638.0         NaN        29273.65
# 3  0000703622503327  06/02/17            NaN     20000.0        49273.65
# 4  0000006928846111  06/02/17        13623.0         NaN        35650.65
